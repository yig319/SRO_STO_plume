# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import glob
from matplotlib import cm
import sys
sys.path.append('../py-characterization/src/XRD/')
from xrd_functions import plot_xrd

# %%
files = ['../data/XRD_RSM/YCG_053/YCG_053 S2 2theta-Omega_Path1_42-49 degree_slow_1.xrdml', '../data/XRD_RSM/YCG_063 2theta-Omega_Path1_42-49 degree_slow_2.xrdml']
labels = ['YG053', 'YG063']
plot_xrd(files, labels, diff=1e3, figsize=(8,4), title='YG053 VS YG063')
