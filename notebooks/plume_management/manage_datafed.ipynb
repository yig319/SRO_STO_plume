# %%
# %load_ext autoreload
# %autoreload 2
import glob
import sys
sys.path.append('../../py-utils/src/')
from datafed_utils import datafed_upload, datafed_update_record

# %%
for file in ['YG053', 'YG054', 'YG055', 'YG056', 'YG057', 'YG058', 'YG059', 'YG060', 
             'YG061', 'YG062', 'YG063', 'YG064', 'YG064_swtich_target', 'YG065']:
    print(glob.glob(f'D:/pld_plumes/SRO_STO_Drexel/{file}*.h5'))
    h5file = glob.glob(f'D:/pld_plumes/SRO_STO_Drexel/{file}*.h5')[0]
    metadata = glob.glob(f'D:/pld_plumes/SRO_STO_Drexel/{file}*.json')[0]
    if isinstance(h5file, str) and isinstance(metadata, str):
        datafed_upload(h5file, 'c/520785518', metadata=metadata, wait=True)
# Out:
# ['D:/pld_plumes/SRO_STO_Drexel\\YG053_YichenGuo_06172024.h5']
# Unable to connect to pypi: <Fault -32500: 'RuntimeError: PyPI no longer supports the XMLRPC package_releases method. Use JSON or Simple API instead. See https://github.com/pypi/warehouse/issues/16642 and https://warehouse.pypa.io/api-reference/xml-rpc.html#deprecated-methods for more information.'>
# (task {
#   id: "task/525717837"
#   type: TT_DATA_PUT
#   status: TS_SUCCEEDED
#   client: "u/yig319"
#   step: 3
#   steps: 4
#   msg: "Finished"
#   ct: 1727232183
#   ut: 1727232448
#   source: "b5d1fa72-53f9-11ee-8a6a-b1038a0991ac/D/pld_plumes/SRO_STO_Drexel/YG053_YichenGuo_06172024.h5"
#   dest: "d/525620063"
# }
# , 'TaskDataReply')
# ['D:/pld_plumes/SRO_STO_Drexel\\YG054_YichenGuo_06252024.h5']
# ...

# %%
files = glob.glob('D:/RHEED/YY302*.h5')
for file in files:
    datafed_upload(file, 'c/525610617', metadata=None, wait=True)
# Out:
# Unable to connect to pypi: <Fault -32500: 'RuntimeError: PyPI no longer supports the XMLRPC package_releases method. Use JSON or Simple API instead. See https://warehouse.pypa.io/api-reference/xml-rpc.html#deprecated-methods for more information.'>
# (task {
#   id: "task/525717936"
#   type: TT_DATA_PUT
#   status: TS_SUCCEEDED
#   client: "u/yig319"
#   step: 3
#   steps: 4
#   msg: "Finished"
#   ct: 1727571083
#   ut: 1727577617
#   source: "b5d1fa72-53f9-11ee-8a6a-b1038a0991ac/D/RHEED/YY302_bottom_electrode_TiN.h5"
#   dest: "d/525620158"
# }
# , 'TaskDataReply')
# Unable to connect to pypi: <Fault -32500: 'RuntimeError: PyPI no longer supports the XMLRPC package_releases method. Use JSON or Simple API instead. See https://warehouse.pypa.io/api-reference/xml-rpc.html#deprecated-methods for more information.'>
# (task {
#   id: "task/525717937"
#   type: TT_DATA_PUT
#   status: TS_SUCCEEDED
#   client: "u/yig319"
#   step: 3
#   steps: 4
#   msg: "Finished"
#   ct: 1727577621
# ...

# %%
file_path = 'D:/RHEED/RHEED_Berkeley_072023_backup.tar.gz'
# metadata = 'D:/pld_plumes/SRO_STO_Drexel/YG064_YichenGuo_09082024.json'
metadata = None
parent_id = 'c/525610611'
datafed_upload(file_path, parent_id, metadata=metadata, wait=False)
# Out:
# Unable to connect to pypi: <Fault -32500: 'RuntimeError: PyPI no longer supports the XMLRPC package_releases method. Use JSON or Simple API instead. See https://warehouse.pypa.io/api-reference/xml-rpc.html#deprecated-methods for more information.'>
# (item {
#   id: "d/525620207"
#   title: "RHEED_Berkeley_072023_backup.tar.gz"
#   size: 0
#   owner: "p/2023_pld_plume"
# }
# task {
#   id: "task/525717985"
#   type: TT_DATA_PUT
#   status: TS_READY
#   client: "u/yig319"
#   step: 0
#   steps: 2
#   msg: "Pending"
#   ct: 1727727291
#   ut: 1727727291
#   source: "b5d1fa72-53f9-11ee-8a6a-b1038a0991ac/D/RHEED/RHEED_Berkeley_072023_backup.tar.gz"
#   dest: "d/525620207"
# }
# , 'DataPutReply')

# %%
file_path = 'D:/RHEED/SRO_STO_Drexel_TSST/YG064_RHEED_container.tar.gz'
metadata = 'D:/pld_plumes/SRO_STO_Drexel/YG064_YichenGuo_09082024.json'
parent_id = 'c/520785518'
datafed_upload(file_path, parent_id, metadata=metadata, wait=False)
# Out:
# Unable to connect to pypi: <Fault -32500: 'RuntimeError: PyPI no longer supports the XMLRPC package_releases method. Use JSON or Simple API instead. See https://warehouse.pypa.io/api-reference/xml-rpc.html#deprecated-methods for more information.'>
# {'header': {'Growth ID': 'YG064', 'User Name': 'YichenGuo', 'Date': '09/08/2024', 'time': '18:04:25', 'Path': 'C:\\Image', 'Chamber': 'Laser 1A', 'Substrate_1': 'SrTiO3', 'Cool Down Atmosphere': 'Vacuum'}, 'target_1': {'Target Material': 'SrRuO3', 'Measured Energy Mean(mJ)': '1.6 mJ/cm^2', 'Ablation-Temperature(°C)': 700.0, 'Ablation-Pressure(mTorr)': 100.0, 'Ablation-Frequency(Hz)': 5.0, 'Ablation-Pulses': 12357.0}}
# (item {
#   id: "d/525620157"
#   title: "YG064_RHEED_container.tar.gz"
#   size: 0
#   owner: "p/2023_pld_plume"
# }
# task {
#   id: "task/525717935"
#   type: TT_DATA_PUT
#   status: TS_READY
#   client: "u/yig319"
#   step: 0
#   steps: 2
#   msg: "Pending"
#   ct: 1727565387
#   ut: 1727565387
# ...

# %%
file_path = 'D:/RHEED/SRO_STO_Drexel_TSST/YG064_RHEED_gaussian_fit_parameters.h5'
parent_id = 'c/520785518'
datafed_upload(file_path, parent_id, metadata=None, wait=False)
# Out:
# Unable to connect to pypi: <Fault -32500: 'RuntimeError: PyPI no longer supports the XMLRPC package_releases method. Use JSON or Simple API instead. See https://github.com/pypi/warehouse/issues/16642 and https://warehouse.pypa.io/api-reference/xml-rpc.html#deprecated-methods for more information.'>
# (item {
#   id: "d/525618020"
#   title: "YG064_RHEED_gaussian_fit_parameters.h5"
#   size: 0
#   owner: "p/2023_pld_plume"
# }
# task {
#   id: "task/525715764"
#   type: TT_DATA_PUT
#   status: TS_READY
#   client: "u/yig319"
#   step: 0
#   steps: 2
#   msg: "Pending"
#   ct: 1726603990
#   ut: 1726603990
#   source: "b5d1fa72-53f9-11ee-8a6a-b1038a0991ac/D/RHEED/SRO_STO_Drexel_TSST/YG064_RHEED_gaussian_fit_parameters.h5"
#   dest: "d/525618020"
# }
# , 'DataPutReply')

# %%
file_path = 'D:/RHEED/SRO_STO_Drexel_TSST/YG065_RHEED_gaussian_fit_parameters.h5'
parent_id = 'c/520785518'
datafed_upload(file_path, parent_id, metadata=None, wait=False)
# Out:
# Unable to connect to pypi: <Fault -32500: 'RuntimeError: PyPI no longer supports the XMLRPC package_releases method. Use JSON or Simple API instead. See https://github.com/pypi/warehouse/issues/16642 and https://warehouse.pypa.io/api-reference/xml-rpc.html#deprecated-methods for more information.'>
# (item {
#   id: "d/525618021"
#   title: "YG065_RHEED_gaussian_fit_parameters.h5"
#   size: 0
#   owner: "p/2023_pld_plume"
# }
# task {
#   id: "task/525715765"
#   type: TT_DATA_PUT
#   status: TS_READY
#   client: "u/yig319"
#   step: 0
#   steps: 2
#   msg: "Pending"
#   ct: 1726604001
#   ut: 1726604001
#   source: "b5d1fa72-53f9-11ee-8a6a-b1038a0991ac/D/RHEED/SRO_STO_Drexel_TSST/YG065_RHEED_gaussian_fit_parameters.h5"
#   dest: "d/525618021"
# }
# , 'DataPutReply')
