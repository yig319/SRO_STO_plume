# %%
import nbformat
from nbconvert import HTMLExporter
from nbconvert.preprocessors import ExecutePreprocessor
from IPython.display import display, HTML
import os

def export_cell_output(cell_source, output_filename="output", format="html"):
    """
    Execute a Jupyter Notebook cell and export its output to a file.
    
    Parameters:
    cell_source (str): The source code of the cell to be executed and exported.
    output_filename (str): The name of the output file (without extension).
    format (str): The format of the output file. Currently supports 'html' only.
    
    Returns:
    str: The name of the created output file.
    """
    # Create a new notebook with a single cell
    notebook = nbformat.v4.new_notebook()
    cell = nbformat.v4.new_code_cell(source=cell_source)
    notebook.cells.append(cell)

    # Execute the notebook
    ep = ExecutePreprocessor(timeout=1200, kernel_name='python3')
    ep.preprocess(notebook, {'metadata': {'path': ''}})

    # Configure the exporter
    if format.lower() == "html":
        exporter = HTMLExporter()
        exporter.template_name = 'classic'
    else:
        raise ValueError("Currently only 'html' format is supported.")

    # Export the executed notebook
    (body, resources) = exporter.from_notebook_node(notebook)

    # Write to file
    output_file = f"{output_filename}.{format}"
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(body)

    return output_file

# Example usage:
# cell_content = """
# print("Hello, World!")
# import matplotlib.pyplot as plt
# plt.plot([1, 2, 3, 4])
# plt.show()
# """
# output_file = export_cell_output(cell_content, "my_output")
# print(f"Output saved as '{output_file}'")

# %%
# YG045

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

#YG045
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG045_YichenGuo_JulianGoddy_05092024.h5'
frame_view_index = 2
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=frame_view_index)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG045_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG045_metrics.csv'

coords = np.array([[30,51], [30,208], [375,43], [377,226]])
viz_parms = {'viz':True, 'index':frame_view_index, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)        
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG045_output")
print(f"Output saved as '{output_file}'")
# Out:
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}
# Output saved as '../growth_logs/YG045_output.html'

# %%
# YG046

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG046_YichenGuo_05162024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG046_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG046_metrics.csv'

coords = np.array([[27,46], [27,203], [372,39], [374,223]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)      
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG046_output")
print(f"Output saved as '{output_file}'")
# Out:
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}
# Output saved as '../growth_logs/YG046_output.html'

# %%
# YG047

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

# YG047
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG047_YichenGuo_05172024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=0)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG047_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG047_metrics.csv'

coords = np.array([[36,39], [35,197], [383,34], [382,218]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)     
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG047_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG047_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %%
# YG048

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

# YG048
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG048_YichenGuo_05302024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG048_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG048_metrics.csv'

coords = np.array([[30,50], [28,209], [376,45], [375,229]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)    
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG048_output")
print(f"Output saved as '{output_file}'")
# Out:
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}
# Output saved as '../growth_logs/YG048_output.html'

# %%
# YG049

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

# YG049
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG049_YichenGuo_06032024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG049_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG049_metrics.csv'

coords = np.array([[22,58], [26,215], [374,52], [374,235]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)   
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG049_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG049_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %%
# YG050

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG050_YichenGuo_06052024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG050_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG050_metrics.csv'

coords = np.array([[25,54], [28,204], [374,48], [371,232]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)  
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG050_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG050_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}

# %%
# YG051

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

# YG051
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG051_YichenGuo_06122024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG051_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG051_metrics.csv'

coords = np.array([[15,52], [19,215], [363,38], [362,223]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG051_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG051_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}

# %%
# YG052

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

# YG052
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG052_YichenGuo_06142024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG052_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG052_metrics.csv'

coords = np.array([[19,52], [21,215], [396,46], [394,230]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG052_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG052_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}

# %%
# YG053

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

# YG053
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG053_YichenGuo_06172024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG053_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG053_metrics.csv'

coords = np.array([[14,50], [16,214], [359,44], [361,229]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG053_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG053_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}

# %%
# YG054

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

# YG054
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG054_YichenGuo_06252024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG054_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG054_metrics.csv'

coords = np.array([[14,55], [15,217], [357,48], [360,234]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG054_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG054_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}

# %%
# YG055

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG055_YichenGuo_06262024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG055_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG055_metrics.csv'

coords = np.array([[17,46], [19,208], [366,39], [364,222]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG055_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG055_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}

# %%
# YG056

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG056_YichenGuo_06282024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG056_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG056_metrics.csv'

coords = np.array([[17,46], [20,208], [366,40], [364,222]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG056_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG056_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}

# %%
# YG057

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG057_YichenGuo_06282024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG057_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG057_metrics.csv'

coords = np.array([[17,46], [20,208], [366,40], [364,222]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG057_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG057_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   {%- elif type == 'text/vnd.mermaid' -%}

# %%
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG058_YichenGuo_06292024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=0)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG058_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG058_metrics.csv'

coords = np.array([[17,40], [20,200], [366,33], [366,217]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
# Out:
# Available datasets: ['1-SrRuO3', '1-SrRuO3_Pre']
# Running analysis for threshold: 200
# Running analysis for threshold: 5
# Running analysis for threshold: flexible
# Results saved to ../../../../datasets/SRO_plume_metrics/YG058_metrics.csv

# %%
# YG058

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG058_YichenGuo_06292024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=0)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG058_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG058_metrics.csv'

coords = np.array([[17,40], [20,200], [366,33], [366,217]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG058_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG058_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %%
# YG063

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG063_YichenGuo_08042024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=0)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG063_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG063_metrics.csv'

coords = np.array([[18,45], [20,209], [363,39], [364,223]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG063_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG063_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %%
# YG064

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG064_YichenGuo_09082024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=0)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG064_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG064_metrics.csv'

coords = np.array([[31,44], [36,206], [375,46], [377,229]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG064_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG064_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %%
# YG065

cell_content = """

import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

#YG065
file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG065_YichenGuo_09092024.h5'
frame_view_index = 2
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=frame_view_index)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG065_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG065_metrics.csv'

coords = np.array([[31,44], [36,206], [375,46], [377,229]])
viz_parms = {'viz':True, 'index':frame_view_index, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)        
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG065_output")
print(f"Output saved as '{output_file}'")

# %%
# YG059

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG059_YichenGuo_07012024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG059_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG059_metrics.csv'

coords = np.array([[15,55], [18,218], [363,48], [362,233]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG059_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG059_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %%
# YG060

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG060_YichenGuo_07032024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG060_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG060_metrics.csv'

coords = np.array([[15,55], [17,218], [364,49], [362,233]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG060_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG060_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %%
# YG061

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG061_YichenGuo_07042024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG061_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG061_metrics.csv'

coords = np.array([[15,55], [17,218], [364,49], [362,233]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG061_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG061_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %%
# YG062

cell_content = """
import pandas as pd
import numpy as np
import glob
import sys
sys.path.append('../../../plume_dynamic_analyzer/src/')
from analyze_function import load_plumes_and_align, run_plume_analysis

file_path = 'D:/pld_plumes/SRO_STO_Drexel/YG062_YichenGuo_07052024.h5'
plumes, ds_name, frame_view, fig = load_plumes_and_align(file_path, frame_view_index=1)
fig.show()

coords_path = '../../../data/Plumes/frame_normalization_coords/YG062_coords.npy'
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
output_csv_path = '../../../data/Plumes/SRO_plume_metrics/YG062_metrics.csv'

coords = np.array([[15,55], [17,218], [364,49], [362,233]])
viz_parms = {'viz':True, 'index':5, 'viz_index':list(np.arange(0, 32, 1)), 'plume_name': ds_name, 'progress_bar':False}
metric_parms = {'time_interval':500e-9, 'threshold_list':[200, 5, 'flexible'], 'rename_dataset':True}

run_plume_analysis(plumes, ds_name, frame_view, coords, coords_path, standard_coords_path, output_csv_path, 
                   viz_parms=viz_parms, metric_parms=metric_parms, align=True)
"""

output_file = export_cell_output(cell_content, "../growth_logs/outputs/YG062_output")
print(f"Output saved as '{output_file}'")
# Out:
# Output saved as '../growth_logs/YG062_output.html'
# c:\Users\yig319\Anaconda3\envs\plume\share\jupyter\nbconvert\templates\base\display_priority.j2:32: UserWarning:
#
# Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.

# %% [markdown]
# ### convert regular csv file to efficiency dataframe

# %%
import numpy as np
# load standard_coords_path
standard_coords_path = '../../../data/Plumes/frame_normalization_coords/standard_coords.npy'
print(np.load(standard_coords_path))
distance = 376-30
distance
# Out:
# [[ 30  51]
#  [ 30 208]
#  [375  43]
#  [377 226]]
# 346

# %%
def pivot_column(df, value_col):
    pivoted = df.pivot_table(
        values=value_col,
        index=['Growth', 'plume_index', 'time_index', 'Pressure (mTorr)', 
               'Temperature (C)', 'Fluence (J per cm2)', 'Repetation rate (Hz)'],
        columns='Threshold',
        aggfunc='first'
    )
    pivoted.columns = [f'{value_col}({col})' for col in pivoted.columns]
    return pivoted

# %%
df_condition = pd.read_excel('../../../../datasets/Sample log.xlsx', sheet_name='SRO')
df_condition = df_condition.loc[16:34, ['Growth', 'Pressure (mTorr)', 'Temperature (C)', 'Fluence (J/cm2)', 'Repetation rate (Hz)']]
df_condition.replace('2 to 1.73', (2+1.73)/2, inplace=True)
df_condition.replace('650 (heater O)', 650, inplace=True)
df_condition.replace('600 (heater O)', 600, inplace=True)
df_condition.replace('700 (heater O)', 700, inplace=True)
df_condition.replace('800 (heater O)', 800, inplace=True)
df_condition['Growth'] = df_condition['Growth'].str.replace(r'LYW_YCG', 'YG', regex=True)
df_condition = df_condition.rename(columns={'Fluence (J/cm2)': 'Fluence (J per cm2)'})

# print('Pressure (mTorr):', df_condition['Pressure (mTorr)'].unique())
# print('Temperature (C):', df_condition['Temperature (C)'].unique())
# print('Fluence (J/cm2):', df_condition['Fluence (J/cm2)'].unique())
# print('Repetation rate (Hz):', df_condition['Repetation rate (Hz)'].unique())
df_condition
# Out:
#    Growth  Pressure (mTorr)  Temperature (C)  Fluence (J per cm2)  \
# 16  YG045              75.0              700             1.692857
# 17  YG046              75.0              700             1.865000
# 18  YG047              75.0              700             2.050000
# 19  YG048              75.0              700             2.050000
# 20  YG049              75.0              700             2.050000
# 21  YG050             100.0              700             2.050000
# 22  YG051              75.0              700             2.050000
# 23  YG052              75.0              650             2.050000
# 24  YG053              75.0              700             1.600000
# 25  YG054              75.0              800             1.600000
# 26  YG055              75.0              600             1.600000
# 27  YG056             100.0              700             1.600000
# 28  YG057              75.0              700             1.230000
# ...

# %%
df_condition['Growth'].unique()
# Out:
# array(['YG045', 'YG046', 'YG047', 'YG048', 'YG049', 'YG050', 'YG051',
#        'YG052', 'YG053', 'YG054', 'YG055', 'YG056', 'YG057', 'YG058',
#        'YG059', 'YG060', 'YG061', 'YG062', 'YG063'], dtype=object)

# %%
for key in df_condition['Growth'].unique():
    file = glob.glob(f'../../../data/Plumes/SRO_plume_metrics/{key}*.csv')[0]
    df = pd.read_csv(file)
    df['Threshold'] = df['Threshold'].astype(str)
    
    print(key)
    merged_df = pd.merge(df, df_condition, on='Growth', how='left')
    merged_df.to_csv(f'../../../data/Plumes/SRO_plume_metrics/{key}_metrics_with_conditions.csv')
    
    # add the efficiency version: seperate area, distance, 
    #     and velocity based on the threshold and remove threshold column to reduce the overall length of dataframe
    area_pivoted = pivot_column(merged_df, 'Area')
    distance_pivoted = pivot_column(merged_df, 'Distance')
    velocity_pivoted = pivot_column(merged_df, 'Velocity')

    merged_df_eff = pd.concat([area_pivoted, distance_pivoted, velocity_pivoted], axis=1)
    merged_df_eff.reset_index(inplace=True)
    merged_df_eff.to_csv(f'../../../data/Plumes/SRO_plume_metrics/{key}_metrics_with_conditions-efficiency.csv')
# Out:
# YG045
# YG046
# YG047
# YG048
# YG049
# YG050
# YG051
# YG052
# YG053
# YG054
# YG055
# YG056
# YG057
# YG058
# YG059
# YG060
# YG061
# YG062
# YG063

# %%
merged_df_eff
# Out:
#       Growth  plume_index  time_index  Pressure (mTorr)  Temperature (C)  \
# 0      YG063            0           0             100.0              700
# 1      YG063            0           1             100.0              700
# 2      YG063            0           2             100.0              700
# 3      YG063            0           3             100.0              700
# 4      YG063            0           4             100.0              700
# ...      ...          ...         ...               ...              ...
# 48635  YG063          379         123             100.0              700
# 48636  YG063          379         124             100.0              700
# 48637  YG063          379         125             100.0              700
# 48638  YG063          379         126             100.0              700
# 48639  YG063          379         127             100.0              700
#
#        Fluence (J per cm2)  Repetation rate (Hz)  Area(200)  Area(5)  \
# ...

# %%
# exam the size of the files    
    
for key in df_condition['Growth'].unique():
    df = pd.read_csv(f'../../../data/Plumes/SRO_plume_metrics/{key}_metrics_with_conditions.csv', index_col=0)
    df_eff = pd.read_csv(f'../../../data/Plumes/SRO_plume_metrics/{key}_metrics_with_conditions-efficiency.csv', index_col=0)
    print(key, df.shape, df_eff.shape)
    for col in df.columns:
        print('--', col, df[col].dtype)
    for col in df_eff.columns:
        print('----', col, df_eff[col].dtype)
# Out:
# YG045 (59904, 11) (19968, 16)
# -- plume_index int64
# -- time_index int64
# -- Distance int64
# -- Velocity float64
# -- Area float64
# -- Threshold object
# -- Growth object
# -- Pressure (mTorr) float64
# -- Temperature (C) int64
# -- Fluence (J/cm2) float64
# -- Repetation rate (Hz) float64
# ---- Growth object
# ---- plume_index int64
# ---- time_index int64
# ---- Pressure (mTorr) float64
# ---- Temperature (C) int64
# ---- Fluence (J/cm2) float64
# ---- Repetation rate (Hz) float64
# ---- Area(200) float64
# ---- Area(5) float64
# ---- Area(flexible) float64
# ---- Distance(200) int64
# ---- Distance(5) int64
# ---- Distance(flexible) int64
# ---- Velocity(200) float64
# ---- Velocity(5) float64
# ---- Velocity(flexible) float64
# YG046 (48000, 11) (16000, 16)
# -- plume_index int64
# -- time_index int64
# -- Distance int64
# -- Velocity float64
# -- Area float64
# -- Threshold object
# -- Growth object
# -- Pressure (mTorr) float64
# -- Temperature (C) int64
# ...
